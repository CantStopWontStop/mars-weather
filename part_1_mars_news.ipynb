# %% [markdown]
# # Module 12 Challenge
# ## Deliverable 1: Scrape Titles and Preview Text from Mars News

# %%
# Import Splinter and BeautifulSoup
from splinter import Browser
from bs4 import BeautifulSoup
from webdriver_manager.chrome import ChromeDriverManager
from selenium import webdriver
import json
import requests

# %%
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
URL  = "https://redplanetscience.com/"
browser.visit(URL)
html = browser.html
sp   = BeautifulSoup(html,"lxml")
print(sp.prettify())
browser.quit()
# Out:
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <link crossorigin="anonymous" href="https://cdn.jsdelivr.net/npm/bootstrap@5.0.0-beta1/dist/css/bootstrap.min.css" integrity="sha384-giJF6kkoqNQ00vy+HMDP7azOuL0xtbfIcaT9wjKHr8RbDVddVHyTfAAsrekwKmP1" rel="stylesheet"/>
#   <link href="css/font.css" rel="stylesheet" type="text/css"/>
#   <link href="css/app.css" rel="stylesheet" type="text/css"/>
#   <link crossorigin="anonymous" href="https://pro.fontawesome.com/releases/v5.10.0/css/all.css" integrity="sha384-AYmEC3Yw5cVb3ZcuHtOA93w35dYTsvhLPVnYs9eStHfGJvOvKxVfELGroGkvsg+p" rel="stylesheet"/>
#   <title>
#    News - Mars Exploration Program
#   </title>
#  </head>
#  <body>
#   <div class="col-md-12">
#    <div class="row">
#     <nav class="navbar navbar-expand-lg navbar-light fixed-top">
#      <div class="container-fluid">
#       <a class="navbar-brand" href="#">
#        <img src="image/nasa.png" width="80"/>
#        <span class="logo">
#         MARS Planet Science
#        </span>
#        <span class="logo1">
#         Exploration Program
#        </span>
#       </a>
#       <button aria-controls="navbarNav" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler" data-bs-target="#navbarNav" data-bs-toggle="collapse" type="button">
#        <span class="navbar-toggler-icon">
#        </span>
#       </button>
#       <div class="collapse navbar-collapse justify-content-end" id="navbarNav">
#        <ul class="navbar-nav">
#         <li class="nav-item">
#          <a aria-current="page" class="nav-link active" href="#">
#           The Red Planet
#          </a>
#         </li>
#         <li class="nav-item">
#          <a class="nav-link" href="#">
#           The Program
#          </a>
#         </li>
#         <li class="nav-item">
#          <a class="nav-link" href="#">
#           News &amp; Events
#          </a>
#         </li>
#         <li class="nav-item">
#          <a class="nav-link" href="#">
#           Multimedia
#          </a>
#         </li>
#         <li class="nav-item">
#          <a class="nav-link" href="#">
#           Missions
#          </a>
#         </li>
#         <li class="nav-item">
#          <a class="nav-link" href="#">
#           More
#          </a>
#         </li>
#         <li class="nav-item nav_search">
#          <a class="nav-link" href="#">
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </nav>
#     <section class="search">
#      <div class="container">
#       <h1>
#        News
#       </h1>
#       <div class="col-md-12 filter">
#        <div class="row">
#         <div class="col-md-3 search_binder">
#          <input class="search_field" name="search" type="text"/>
#          <input class="search_submit" name="search" type="text"/>
#         </div>
#         <div class="col-md-3">
#          <select aria-label="Default select example" class="form-select" id="year">
#           <option selected="">
#            Latest
#           </option>
#           <option>
#            2020
#           </option>
#           <option>
#            2019
#           </option>
#          </select>
#         </div>
#         <div class="col-md-3">
#          <select aria-label="Default select example" class="form-select" id="cat">
#           <option selected="">
#            All Categories
#           </option>
#           <option>
#            Feature Stories
#           </option>
#           <option>
#            Press Releases
#           </option>
#           <option>
#            Status Reports
#           </option>
#          </select>
#         </div>
#         <div class="col-md-3">
#         </div>
#        </div>
#       </div>
#      </div>
#     </section>
#     <section class="image_and_description_container">
#      <div class="container" id="news">
#       <div class="col-md-12">
#        <hr/>
#        <div class="row">
#         <div class="col-md-4">
#          <div class="list_image">
#           <img src="https://mars.nasa.gov/system/news_items/list_view_images/8677_airplane20200521-320.jpg"/>
#          </div>
#         </div>
#         <div class="col-md-8">
#          <div class="list_text">
#           <div class="list_date">
#            December 12, 2022
#           </div>
#           <div class="content_title">
#            Air Deliveries Bring NASA's Perseverance Mars Rover Closer to Launch
#           </div>
#           <div class="article_teaser_body">
#            A NASA Wallops Flight Facility cargo plane transported more than two tons of equipment — including the rover's sample collection tubes — to Florida for this summer's liftoff.
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="col-md-12">
#        <hr/>
#        <div class="row">
#         <div class="col-md-4">
#          <div class="list_image">
#           <img src="https://mars.nasa.gov/system/news_items/list_view_images/8770_PIA24047-320.jpg"/>
#          </div>
#         </div>
#         <div class="col-md-8">
#          <div class="list_text">
#           <div class="list_date">
#            December 11, 2022
#           </div>
#           <div class="content_title">
#            NASA's Perseverance Rover Will Peer Beneath Mars' Surface
#           </div>
#           <div class="article_teaser_body">
#            The agency's newest rover will use the first ground-penetrating radar instrument on the Martian surface to help search for signs of past microbial life.
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="col-md-12">
#        <hr/>
#        <div class="row">
#         <div class="col-md-4">
#          <div class="list_image">
#           <img src="https://mars.nasa.gov/system/news_items/list_view_images/8712_PIA23720-320x240.jpg"/>
#          </div>
#         </div>
#         <div class="col-md-8">
#          <div class="list_text">
#           <div class="list_date">
#            December 11, 2022
#           </div>
#           <div class="content_title">
#            6 Things to Know About NASA's Ingenuity Mars Helicopter
#           </div>
#           <div class="article_teaser_body">
#            The first helicopter attempting to fly on another planet is a marvel of engineering. Get up to speed with these key facts about its plans.
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="col-md-12">
#        <hr/>
#        <div class="row">
#         <div class="col-md-4">
#          <div class="list_image">
#           <img src="https://mars.nasa.gov/system/news_items/list_view_images/8716_PIA23499-320x240.jpg"/>
#          </div>
#         </div>
#         <div class="col-md-8">
#          <div class="list_text">
#           <div class="list_date">
#            December 11, 2022
#           </div>
#           <div class="content_title">
#            NASA to Broadcast Mars 2020 Perseverance Launch, Prelaunch Activities
#           </div>
#           <div class="article_teaser_body">
#            Starting July 27, news activities will cover everything from mission engineering and science to returning samples from Mars to, of course, the launch itself.
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="col-md-12">
#        <hr/>
#        <div class="row">
#         <div class="col-md-4">
#          <div class="list_image">
#           <img src="https://mars.nasa.gov/system/news_items/list_view_images/8568_PIA23515_annotated-globe-320x240.gif"/>
#          </div>
#         </div>
#         <div class="col-md-8">
#          <div class="list_text">
#           <div class="list_date">
#            December 10, 2022
#           </div>
#           <div class="content_title">
#            NASA's Treasure Map for Water Ice on Mars
#           </div>
#           <div class="article_teaser_body">
#            A new study identifies frozen water just below the Martian surface, where astronauts could easily dig it up.
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="col-md-12">
#        <hr/>
#        <div class="row">
#         <div class="col-md-4">
#          <div class="list_image">
#           <img src="https://mars.nasa.gov/system/news_items/list_view_images/8503_PIA23319-MAIN-226.jpg"/>
#          </div>
#         </div>
#         <div class="col-md-8">
#          <div class="list_text">
#           <div class="list_date">
#            December 6, 2022
#           </div>
#           <div class="content_title">
#            Robotic Toolkit Added to NASA's Mars 2020 Rover
#           </div>
#           <div class="article_teaser_body">
#            The bit carousel, which lies at the heart of the rover's Sample Caching System, is now aboard NASA's newest rover.
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="col-md-12">
#        <hr/>
#        <div class="row">
#         <div class="col-md-4">
#          <div class="list_image">
#           <img src="https://mars.nasa.gov/system/news_items/list_view_images/8662_video-collage-perseverance-320x240.jpg"/>
#          </div>
#         </div>
#         <div class="col-md-8">
#          <div class="list_text">
#           <div class="list_date">
#            November 26, 2022
#           </div>
#           <div class="content_title">
#            Meet the People Behind NASA's Perseverance Rover
#           </div>
#           <div class="article_teaser_body">
#            These are the scientists and engineers who built NASA's next Mars rover and who will guide it to a safe landing in Jezero Crater.
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="col-md-12">
#        <hr/>
#        <div class="row">
#         <div class="col-md-4">
#          <div class="list_image">
#           <img src="https://mars.nasa.gov/system/news_items/list_view_images/8659_1-PIA23883-MAIN-320x240.jpg"/>
#          </div>
#         </div>
#         <div class="col-md-8">
#          <div class="list_text">
#           <div class="list_date">
#            November 26, 2022
#           </div>
#           <div class="content_title">
#            Alabama High School Student Names NASA's Mars Helicopter
#           </div>
#           <div class="article_teaser_body">
#            Vaneeza Rupani's essay was chosen as the name for the small spacecraft, which will mark NASA's first attempt at powered flight on another planet.
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="col-md-12">
#        <hr/>
#        <div class="row">
#         <div class="col-md-4">
#          <div class="list_image">
#           <img src="https://mars.nasa.gov/system/news_items/list_view_images/8805_1-MOXIE-PIA24176-320.gif"/>
#          </div>
#         </div>
#         <div class="col-md-8">
#          <div class="list_text">
#           <div class="list_date">
#            November 26, 2022
#           </div>
#           <div class="content_title">
#            MOXIE Could Help Future Rockets Launch Off Mars
#           </div>
#           <div class="article_teaser_body">
#            NASA's Perseverance rover carries a device to convert Martian air into oxygen that, if produced on a larger scale, could be used not just for breathing, but also for fuel.
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="col-md-12">
#        <hr/>
#        <div class="row">
#         <div class="col-md-4">
#          <div class="list_image">
#           <img src="https://mars.nasa.gov/system/news_items/list_view_images/8782_PIA-23989-320.jpg"/>
#          </div>
#         </div>
#         <div class="col-md-8">
#          <div class="list_text">
#           <div class="list_date">
#            November 22, 2022
#           </div>
#           <div class="content_title">
#            Sensors on Mars 2020 Spacecraft Answer Long-Distance Call From Earth
#           </div>
#           <div class="article_teaser_body">
#            Instruments tailored to collect data during the descent of NASA's next rover through the Red Planet's atmosphere have been checked in flight.
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="col-md-12">
#        <hr/>
#        <div class="row">
#         <div class="col-md-4">
#          <div class="list_image">
#           <img src="https://mars.nasa.gov/system/news_items/list_view_images/8744_PIA22957-226.jpg"/>
#          </div>
#         </div>
#         <div class="col-md-8">
#          <div class="list_text">
#           <div class="list_date">
#            November 21, 2022
#           </div>
#           <div class="content_title">
#            NASA Engineers Checking InSight's Weather Sensors
#           </div>
#           <div class="article_teaser_body">
#            An electronics issue is suspected to be preventing the sensors from sharing their data about Mars weather with the spacecraft.
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="col-md-12">
#        <hr/>
#        <div class="row">
#         <div class="col-md-4">
#          <div class="list_image">
#           <img src="https://mars.nasa.gov/system/news_items/list_view_images/8622_1-PIA23764-RoverNamePlateonMars-320x240.jpg"/>
#          </div>
#         </div>
#         <div class="col-md-8">
#          <div class="list_text">
#           <div class="list_date">
#            November 20, 2022
#           </div>
#           <div class="content_title">
#            Virginia Middle School Student Earns Honor of Naming NASA's Next Mars Rover
#           </div>
#           <div class="article_teaser_body">
#            NASA chose a seventh-grader from Virginia as winner of the agency's "Name the Rover" essay contest. Alexander Mather's entry for "Perseverance" was voted tops among 28,000 entries.
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="col-md-12">
#        <hr/>
#        <div class="row">
#         <div class="col-md-4">
#          <div class="list_image">
#           <img src="https://mars.nasa.gov/system/news_items/list_view_images/8528_PIA23376-320x240.jpg"/>
#          </div>
#         </div>
#         <div class="col-md-8">
#          <div class="list_text">
#           <div class="list_date">
#            November 16, 2022
#           </div>
#           <div class="content_title">
#            HiRISE Views NASA's InSight and Curiosity on Mars
#           </div>
#           <div class="article_teaser_body">
#            New images taken from space offer the clearest orbital glimpse yet of InSight as well as a view of Curiosity rolling along.
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="col-md-12">
#        <hr/>
#        <div class="row">
#         <div class="col-md-4">
#          <div class="list_image">
#           <img src="https://mars.nasa.gov/system/news_items/list_view_images/8812_Perseverance-festooning-collage-320.jpg"/>
#          </div>
#         </div>
#         <div class="col-md-8">
#          <div class="list_text">
#           <div class="list_date">
#            November 14, 2022
#           </div>
#           <div class="content_title">
#            5 Hidden Gems Are Riding Aboard NASA's Perseverance Rover
#           </div>
#           <div class="article_teaser_body">
#            The symbols, mottos, and small objects added to the agency's newest Mars rover serve a variety of purposes, from functional to decorative.
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="col-md-12">
#        <hr/>
#        <div class="row">
#         <div class="col-md-4">
#          <div class="list_image">
#           <img src="https://mars.nasa.gov/system/news_items/list_view_images/8695_24732_PIA23499-226.jpg"/>
#          </div>
#         </div>
#         <div class="col-md-8">
#          <div class="list_text">
#           <div class="list_date">
#            November 14, 2022
#           </div>
#           <div class="content_title">
#            The Launch Is Approaching for NASA's Next Mars Rover, Perseverance
#           </div>
#           <div class="article_teaser_body">
#            The Red Planet's surface has been visited by eight NASA spacecraft. The ninth will be the first that includes a roundtrip ticket in its flight plan.
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <hr class="container" style="margin: 25px auto;width: 83%;"/>
#      <button class="btn disable" id="more" onclick="populateContent()">
#       More
#      </button>
#     </section>
#     <section class="last_news">
#      <div class="container">
#       <div class="row">
#        <div class="col-12">
#         <h2>
#          You Might Also Like
#         </h2>
#        </div>
#        <!--  <a class=" prev" href="#carouselExampleIndicators2" role="button" data-slide="prev">
#                   <i class="fas fa-angle-left"></i>
#                   </a>
#                   <a class=" next" href="#carouselExampleIndicators2" role="button" data-slide="next">
#                   <i class="fas fa-angle-right"></i>
#                   </a> -->
#        <div class="col-12">
#         <div class="carousel slide" data-ride="carousel" id="carouselExampleIndicators2">
#          <div class="carousel-inner">
#           <div class="carousel-item active">
#            <div class="row">
#             <div class="col-md-4 mb-3">
#              <div class="card">
#               <img alt="100%x280" class="img-fluid" src="https://mars.nasa.gov/system/news_items/main_images/8716_PIA23499-16.jpg"/>
#               <div class="card-body">
#                <p class="card-text">
#                 NASA to Broadcast Mars 2020 Perseverance Launch, Prelaunch Activities
#                </p>
#               </div>
#              </div>
#             </div>
#             <div class="col-md-4 mb-3">
#              <div class="card">
#               <img alt="100%x280" class="img-fluid" src="https://mars.nasa.gov/system/news_items/main_images/8716_PIA23499-16.jpg"/>
#               <div class="card-body">
#                <p class="card-text">
#                 The Launch Is Approaching for NASA's Next Mars Rover, Perseverance
#                </p>
#               </div>
#              </div>
#             </div>
#             <div class="col-md-4 mb-3">
#              <div class="card">
#               <img alt="100%x280" class="img-fluid" src="https://mars.nasa.gov/system/news_items/main_images/8692_PIA23920-web.jpg"/>
#               <div class="card-body">
#                <p class="card-text">
#                 NASA to Hold Mars 2020 Perseverance Rover Launch Briefing
#                </p>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#           <div class="carousel-item">
#            <div class="row">
#             <div class="col-md-4 mb-3">
#              <div class="card">
#               <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532771098148-525cefe10c23?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=3f317c1f7a16116dec454fbc267dd8e4"/>
#               <div class="card-body">
#                <p class="card-text">
#                 With supporting text below as a natural lead-in to additional content.
#                </p>
#               </div>
#              </div>
#             </div>
#             <div class="col-md-4 mb-3">
#              <div class="card">
#               <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532715088550-62f09305f765?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=ebadb044b374504ef8e81bdec4d0e840"/>
#               <div class="card-body">
#                <p class="card-text">
#                 With supporting text below as a natural lead-in to additional content.
#                </p>
#               </div>
#              </div>
#             </div>
#             <div class="col-md-4 mb-3">
#              <div class="card">
#               <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1506197603052-3cc9c3a201bd?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=0754ab085804ae8a3b562548e6b4aa2e"/>
#               <div class="card-body">
#                <p class="card-text">
#                 With supporting text below as a natural lead-in to additional content.
#                </p>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#           <div class="carousel-item">
#            <div class="row">
#             <div class="col-md-4 mb-3">
#              <div class="card">
#               <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1507525428034-b723cf961d3e?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=ee8417f0ea2a50d53a12665820b54e23"/>
#               <div class="card-body">
#                <p class="card-text">
#                 With supporting text below as a natural lead-in to additional content.
#                </p>
#               </div>
#              </div>
#             </div>
#             <div class="col-md-4 mb-3">
#              <div class="card">
#               <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532777946373-b6783242f211?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=8ac55cf3a68785643998730839663129"/>
#               <div class="card-body">
#                <p class="card-text">
#                 With supporting text below as a natural lead-in to additional content.
#                </p>
#               </div>
#              </div>
#             </div>
#             <div class="col-md-4 mb-3">
#              <div class="card">
#               <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532763303805-529d595877c5?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=5ee4fd5d19b40f93eadb21871757eda6"/>
#               <div class="card-body">
#                <p class="card-text">
#                 With supporting text below as a natural lead-in to additional content.
#                </p>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </section>
#     <section class="footer">
#      <div class="container">
#       <div class="col-md-12">
#        <div class="row">
#         <div class="col-md-3">
#          <h5>
#           The Red Planet
#          </h5>
#          <ul>
#           <li>
#            Dashboard
#           </li>
#           <li>
#            Science Goals
#           </li>
#           <li>
#            The Planet
#           </li>
#          </ul>
#         </div>
#         <div class="col-md-3">
#          <h5>
#           The Program
#          </h5>
#          <ul>
#           <li>
#            Mission Statement
#           </li>
#           <li>
#            About the Program
#           </li>
#           <li>
#            Organization Why Mars?
#           </li>
#          </ul>
#         </div>
#         <div class="col-md-3">
#          <h5>
#           Multimedia
#          </h5>
#          <ul>
#           <li>
#            Images
#           </li>
#           <li>
#            Videos
#           </li>
#           <li>
#            More Resources
#           </li>
#          </ul>
#         </div>
#         <div class="col-md-3">
#          <h5>
#           Missions
#          </h5>
#          <ul>
#           <li>
#            Past
#           </li>
#           <li>
#            Present
#           </li>
#           <li>
#            Future
#           </li>
#          </ul>
#         </div>
#        </div>
#       </div>
#      </div>
#     </section>
#     <script src="https://code.jquery.com/jquery-1.12.4.min.js" type="text/javascript">
#     </script>
#     <script src="https://cdn.jsdelivr.net/npm/@popperjs/core@2.5.4/dist/umd/popper.min.js">
#     </script>
#     <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.0.0-beta1/dist/js/bootstrap.min.js">
#     </script>
#     <script src="js/app.js">
#     </script>
#    </div>
#   </div>
#  </body>
# </html>

# %% [markdown]
# ### Step 1: Visit the Website
#
# 1. Use automated browsing to visit the [Mars NASA news site](https://redplanetscience.com). Inspect the page to identify which elements to scrape.
#
#       > **Hint** To identify which elements to scrape, you might want to inspect the page by using Chrome DevTools.

# %% [markdown]
# ### Step 2: Scrape the Website
#
# Create a Beautiful Soup object and use it to extract text elements from the website.

# %%
# Create a Beautiful Soup 

section = sp.find('section',class_ = "image_and_description_container")
articles = section.find_all('div', class_='row')


articles_dict   = []


for row in articles:
    title_row = row.find('div', class_='content_title')
    prev_row = row.find('div', class_='article_teaser_body')
    
    
    img_row = row.find('div', class_='list_image')
    img = img_row.find('img')
    
    dictionary = {'title': title_row.text,
    'preview': prev_row.text,
    'image': img['src']}
    articles_dict.append(dictionary)
    
print(articles_dict)
# Out:
# [{'title': "Air Deliveries Bring NASA's Perseverance Mars Rover Closer to Launch", 'preview': "A NASA Wallops Flight Facility cargo plane transported more than two tons of equipment — including the rover's sample collection tubes — to Florida for this summer's liftoff.", 'image': 'https://mars.nasa.gov/system/news_items/list_view_images/8677_airplane20200521-320.jpg'}, {'title': "NASA's Perseverance Rover Will Peer Beneath Mars' Surface ", 'preview': "The agency's newest rover will use the first ground-penetrating radar instrument on the Martian surface to help search for signs of past microbial life. ", 'image': 'https://mars.nasa.gov/system/news_items/list_view_images/8770_PIA24047-320.jpg'}, {'title': "6 Things to Know About NASA's Ingenuity Mars Helicopter", 'preview': 'The first helicopter attempting to fly on another planet is a marvel of engineering. Get up to speed with these key facts about its plans.', 'image': 'https://mars.nasa.gov/system/news_items/list_view_images/8712_PIA23720-320x240.jpg'}, {'title': 'NASA to Broadcast Mars 2020 Perseverance Launch, Prelaunch Activities', 'preview': 'Starting July 27, news activities will cover everything from mission engineering and science to returning samples from Mars to, of course, the launch itself.', 'image': 'https://mars.nasa.gov/system/news_items/list_view_images/8716_PIA23499-320x240.jpg'}, {'title': "NASA's Treasure Map for Water Ice on Mars", 'preview': 'A new study identifies frozen water just below the Martian surface, where astronauts could easily dig it up.', 'image': 'https://mars.nasa.gov/system/news_items/list_view_images/8568_PIA23515_annotated-globe-320x240.gif'}, {'title': "Robotic Toolkit Added to NASA's Mars 2020 Rover", 'preview': "The bit carousel, which lies at the heart of the rover's Sample Caching System, is now aboard NASA's newest rover. ", 'image': 'https://mars.nasa.gov/system/news_items/list_view_images/8503_PIA23319-MAIN-226.jpg'}, {'title': "Meet the People Behind NASA's Perseverance Rover", 'preview': "These are the scientists and engineers who built NASA's next Mars rover and who will guide it to a safe landing in Jezero Crater. ", 'image': 'https://mars.nasa.gov/system/news_items/list_view_images/8662_video-collage-perseverance-320x240.jpg'}, {'title': "Alabama High School Student Names NASA's Mars Helicopter", 'preview': "Vaneeza Rupani's essay was chosen as the name for the small spacecraft, which will mark NASA's first attempt at powered flight on another planet.", 'image': 'https://mars.nasa.gov/system/news_items/list_view_images/8659_1-PIA23883-MAIN-320x240.jpg'}, {'title': 'MOXIE Could Help Future Rockets Launch Off Mars', 'preview': "NASA's Perseverance rover carries a device to convert Martian air into oxygen that, if produced on a larger scale, could be used not just for breathing, but also for fuel.", 'image': 'https://mars.nasa.gov/system/news_items/list_view_images/8805_1-MOXIE-PIA24176-320.gif'}, {'title': 'Sensors on Mars 2020 Spacecraft Answer Long-Distance Call From Earth', 'preview': "Instruments tailored to collect data during the descent of NASA's next rover through the Red Planet's atmosphere have been checked in flight.", 'image': 'https://mars.nasa.gov/system/news_items/list_view_images/8782_PIA-23989-320.jpg'}, {'title': "NASA Engineers Checking InSight's Weather Sensors", 'preview': 'An electronics issue is suspected to be preventing the sensors from sharing their data about Mars weather with the spacecraft.', 'image': 'https://mars.nasa.gov/system/news_items/list_view_images/8744_PIA22957-226.jpg'}, {'title': "Virginia Middle School Student Earns Honor of Naming NASA's Next Mars Rover", 'preview': 'NASA chose a seventh-grader from Virginia as winner of the agency\'s "Name the Rover" essay contest. Alexander Mather\'s entry for "Perseverance" was voted tops among 28,000 entries. ', 'image': 'https://mars.nasa.gov/system/news_items/list_view_images/8622_1-PIA23764-RoverNamePlateonMars-320x240.jpg'}, {'title': "HiRI ...

# %% [markdown]
# ### Step 3: Store the Results
#
# Extract the titles and preview text of the news articles that you scraped. Store the scraping results in Python data structures as follows:
#
# * Store each title-and-preview pair in a Python dictionary. And, give each dictionary two keys: `title` and `preview`. An example is the following:
#
#   ```python
#   {'title': "Mars Rover Begins Mission!",
#         'preview': "NASA's Mars Rover begins a multiyear mission to collect data about the little-explored planet."}
#   ```
#
# * Store all the dictionaries in a Python list.
#
# * Print the list in your notebook.

# %%
# Create an empty list to store the dictionaries
print(articles_dict)
# Out:
# [{'title': "Air Deliveries Bring NASA's Perseverance Mars Rover Closer to Launch", 'preview': "A NASA Wallops Flight Facility cargo plane transported more than two tons of equipment — including the rover's sample collection tubes — to Florida for this summer's liftoff.", 'image': 'https://mars.nasa.gov/system/news_items/list_view_images/8677_airplane20200521-320.jpg'}, {'title': "NASA's Perseverance Rover Will Peer Beneath Mars' Surface ", 'preview': "The agency's newest rover will use the first ground-penetrating radar instrument on the Martian surface to help search for signs of past microbial life. ", 'image': 'https://mars.nasa.gov/system/news_items/list_view_images/8770_PIA24047-320.jpg'}, {'title': "6 Things to Know About NASA's Ingenuity Mars Helicopter", 'preview': 'The first helicopter attempting to fly on another planet is a marvel of engineering. Get up to speed with these key facts about its plans.', 'image': 'https://mars.nasa.gov/system/news_items/list_view_images/8712_PIA23720-320x240.jpg'}, {'title': 'NASA to Broadcast Mars 2020 Perseverance Launch, Prelaunch Activities', 'preview': 'Starting July 27, news activities will cover everything from mission engineering and science to returning samples from Mars to, of course, the launch itself.', 'image': 'https://mars.nasa.gov/system/news_items/list_view_images/8716_PIA23499-320x240.jpg'}, {'title': "NASA's Treasure Map for Water Ice on Mars", 'preview': 'A new study identifies frozen water just below the Martian surface, where astronauts could easily dig it up.', 'image': 'https://mars.nasa.gov/system/news_items/list_view_images/8568_PIA23515_annotated-globe-320x240.gif'}, {'title': "Robotic Toolkit Added to NASA's Mars 2020 Rover", 'preview': "The bit carousel, which lies at the heart of the rover's Sample Caching System, is now aboard NASA's newest rover. ", 'image': 'https://mars.nasa.gov/system/news_items/list_view_images/8503_PIA23319-MAIN-226.jpg'}, {'title': "Meet the People Behind NASA's Perseverance Rover", 'preview': "These are the scientists and engineers who built NASA's next Mars rover and who will guide it to a safe landing in Jezero Crater. ", 'image': 'https://mars.nasa.gov/system/news_items/list_view_images/8662_video-collage-perseverance-320x240.jpg'}, {'title': "Alabama High School Student Names NASA's Mars Helicopter", 'preview': "Vaneeza Rupani's essay was chosen as the name for the small spacecraft, which will mark NASA's first attempt at powered flight on another planet.", 'image': 'https://mars.nasa.gov/system/news_items/list_view_images/8659_1-PIA23883-MAIN-320x240.jpg'}, {'title': 'MOXIE Could Help Future Rockets Launch Off Mars', 'preview': "NASA's Perseverance rover carries a device to convert Martian air into oxygen that, if produced on a larger scale, could be used not just for breathing, but also for fuel.", 'image': 'https://mars.nasa.gov/system/news_items/list_view_images/8805_1-MOXIE-PIA24176-320.gif'}, {'title': 'Sensors on Mars 2020 Spacecraft Answer Long-Distance Call From Earth', 'preview': "Instruments tailored to collect data during the descent of NASA's next rover through the Red Planet's atmosphere have been checked in flight.", 'image': 'https://mars.nasa.gov/system/news_items/list_view_images/8782_PIA-23989-320.jpg'}, {'title': "NASA Engineers Checking InSight's Weather Sensors", 'preview': 'An electronics issue is suspected to be preventing the sensors from sharing their data about Mars weather with the spacecraft.', 'image': 'https://mars.nasa.gov/system/news_items/list_view_images/8744_PIA22957-226.jpg'}, {'title': "Virginia Middle School Student Earns Honor of Naming NASA's Next Mars Rover", 'preview': 'NASA chose a seventh-grader from Virginia as winner of the agency\'s "Name the Rover" essay contest. Alexander Mather\'s entry for "Perseverance" was voted tops among 28,000 entries. ', 'image': 'https://mars.nasa.gov/system/news_items/list_view_images/8622_1-PIA23764-RoverNamePlateonMars-320x240.jpg'}, {'title': "HiRI ...

# %% [markdown]
# ### (Optional) Step 4: Export the Data
#
# Optionally, store the scraped data in a file or database (to ease sharing the data with others). To do so, export the scraped data to either a JSON file or a MongoDB database.

# %%
# Export data to JSON
articles = json.dumps(articles_dict, indent = 1) 
articles
# Out:
# '[\n {\n  "title": "Air Deliveries Bring NASA\'s Perseverance Mars Rover Closer to Launch",\n  "preview": "A NASA Wallops Flight Facility cargo plane transported more than two tons of equipment \\u2014 including the rover\'s sample collection tubes \\u2014 to Florida for this summer\'s liftoff.",\n  "image": "https://mars.nasa.gov/system/news_items/list_view_images/8677_airplane20200521-320.jpg"\n },\n {\n  "title": "NASA\'s Perseverance Rover Will Peer Beneath Mars\' Surface ",\n  "preview": "The agency\'s newest rover will use the first ground-penetrating radar instrument on the Martian surface to help search for signs of past microbial life. ",\n  "image": "https://mars.nasa.gov/system/news_items/list_view_images/8770_PIA24047-320.jpg"\n },\n {\n  "title": "6 Things to Know About NASA\'s Ingenuity Mars Helicopter",\n  "preview": "The first helicopter attempting to fly on another planet is a marvel of engineering. Get up to speed with these key facts about its plans.",\n  "image": "https://mars.nasa.gov/system/news_items/list_view_images/8712_PIA23720-320x240.jpg"\n },\n {\n  "title": "NASA to Broadcast Mars 2020 Perseverance Launch, Prelaunch Activities",\n  "preview": "Starting July 27, news activities will cover everything from mission engineering and science to returning samples from Mars to, of course, the launch itself.",\n  "image": "https://mars.nasa.gov/system/news_items/list_view_images/8716_PIA23499-320x240.jpg"\n },\n {\n  "title": "NASA\'s Treasure Map for Water Ice on Mars",\n  "preview": "A new study identifies frozen water just below the Martian surface, where astronauts could easily dig it up.",\n  "image": "https://mars.nasa.gov/system/news_items/list_view_images/8568_PIA23515_annotated-globe-320x240.gif"\n },\n {\n  "title": "Robotic Toolkit Added to NASA\'s Mars 2020 Rover",\n  "preview": "The bit carousel, which lies at the heart of the rover\'s Sample Caching System, is now aboard NASA\'s newest rover. ",\n  "image": "https://mars.nasa.gov/system/news_items/list_view_images/8503_PIA23319-MAIN-226.jpg"\n },\n {\n  "title": "Meet the People Behind NASA\'s Perseverance Rover",\n  "preview": "These are the scientists and engineers who built NASA\'s next Mars rover and who will guide it to a safe landing in Jezero Crater. ",\n  "image": "https://mars.nasa.gov/system/news_items/list_view_images/8662_video-collage-perseverance-320x240.jpg"\n },\n {\n  "title": "Alabama High School Student Names NASA\'s Mars Helicopter",\n  "preview": "Vaneeza Rupani\'s essay was chosen as the name for the small spacecraft, which will mark NASA\'s first attempt at powered flight on another planet.",\n  "image": "https://mars.nasa.gov/system/news_items/list_view_images/8659_1-PIA23883-MAIN-320x240.jpg"\n },\n {\n  "title": "MOXIE Could Help Future Rockets Launch Off Mars",\n  "preview": "NASA\'s Perseverance rover carries a device to convert Martian air into oxygen that, if produced on a larger scale, could be used not just for breathing, but also for fuel.",\n  "image": "https://mars.nasa.gov/system/news_items/list_view_images/8805_1-MOXIE-PIA24176-320.gif"\n },\n {\n  "title": "Sensors on Mars 2020 Spacecraft Answer Long-Distance Call From Earth",\n  "preview": "Instruments tailored to collect data during the descent of NASA\'s next rover through the Red Planet\'s atmosphere have been checked in flight.",\n  "image": "https://mars.nasa.gov/system/news_items/list_view_images/8782_PIA-23989-320.jpg"\n },\n {\n  "title": "NASA Engineers Checking InSight\'s Weather Sensors",\n  "preview": "An electronics issue is suspected to be preventing the sensors from sharing their data about Mars weather with the spacecraft.",\n  "image": "https://mars.nasa.gov/system/news_items/list_view_images/8744_PIA22957-226.jpg"\n },\n {\n  "title": "Virginia Middle School Student Earns Honor of Naming NASA\'s Next Mars Rover",\n  "preview": "NASA chose a seventh-grader from Virginia as winner of the agency\'s \\"Name the Rover\\" essay contest. Alexan ...

# %%
with open("sample.json", "w") as outfile:
    json.dump(articles_dict, outfile)
